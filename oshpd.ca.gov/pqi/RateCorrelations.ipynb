# %% [markdown]
# # Correlation among Prevention Quality Indicators (PQIs)
#
# Prevention Quality Indicators (PQIs)
#
# County-by-county correlations for OSHPD Prevention Quality Indicators.
#
# A high correlation indicates that across many counties, counties that have a high risk-adjusted rate for indicator_1 also has a high risk-adjusted rate for indicator_2. The counties in this dataset are the counties of the locations of the hospitals where patients are treated, not the counties of the residences of the patients. Because small counties will have a small number of hospitals and patients are likely to visit hospitals in other counties, small counties may have inaccurate correlations.
#
# A high correlation does not indicate that individuals in a county are highly likely to have both conditions. For instance, it could be that hospitals that specialize the diseases of one indicator are also well know for treating the other. In such a case, the correlation is becase the treatements of the diseases are correlated, not that the prevalence of the diseses are corelated.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from ambry import get_library
l = get_library()
b = l.bundle('oshpd.ca.gov-pqi-0.0.3')
p = b.partition('oshpd.ca.gov-pqi-pqi-county-0.0.3').localize()

# %%
# Get all of the risk adjusted rates, and remove all of the composites, because those will be, by definition, 
# correlated with their components. 
cols = [c for c in df.columns if (c.endswith('_risk_adjusted_rate') and 'composite' not in c)]
short_cols = [c.replace('_risk_adjusted_rate','') for c in cols]
dfrar = df[cols]
dfrar.columns = short_cols

corrm=dfrar.corr()
# Correlation matrices are symmetric around the diagonal, so we only need one half,
# the lower triangle
corrm.loc[:,:] = np.tril(corrm,k=-1)

# %%
# Stacking puts the column headings into a multi-index
# Reseting the index puts the two levels of the multi-index into columns
corrstk = corrm.stack().reset_index().copy()

corrstk.columns = ["indicator_1", "indicator_2", 'correlation']
corrstk.sort('correlation', ascending=False)

# Removing correlation == 0 removes the duplicate indicator pairs; since we took only
# the bottom of the triangle, all of the duplicate pairs on the top are 0
corrstk[corrstk.correlation!=0].sort('correlation', ascending = False)
# Out:
#                                            indicator_1  \
# 67                                 pqi_8_heart_failure
# 161  pqi_16_lower_extremity_amputation_among_patien...
# 107                     pqi_12_urinary_tract_infection
# 158  pqi_16_lower_extremity_amputation_among_patien...
# 94                          pqi_11_bacterial_pneumonia
# 111                     pqi_12_urinary_tract_infection
# 81                                  pqi_10_dehydration
# 97                          pqi_11_bacterial_pneumonia
# 68                                 pqi_8_heart_failure
# 106                     pqi_12_urinary_tract_infection
# 41                pqi_5_copd_or_asthma_in_older_adults
# 109                     pqi_12_urinary_tract_infection
# 133                       pqi_14_uncontrolled_diabetes
# 138                       pqi_14_uncontrolled_diabetes
# 132                       pqi_14_uncontrolled_diabetes
# 110                     pqi_12_urinary_tract_infection
# 164  pqi_16_lower_extremity_amputation_among_patien...
# 159  pqi_16_lower_extremity_amputation_among_patien...
# 136                       pqi_14_uncontrolled_diabetes
# 83                                  pqi_10_dehydration
# 69                                 pqi_8_heart_failure
# 93                          pqi_11_bacterial_pneumonia
# 91                          pqi_11_bacterial_pneumonia
# 80                                  pqi_10_dehydration
# 54                                  pqi_7_hypertension
# 135                       pqi_14_uncontrolled_diabetes
# 137                       pqi_14_uncontrolled_diabetes
# 153                    pqi_15_asthma_in_younger_adults
# 96                          pqi_11_bacterial_pneumonia
# 160  pqi_16_lower_extremity_amputation_among_patien...
# ..                                                 ...
# 39                pqi_5_copd_or_asthma_in_older_adults
# 162  pqi_16_lower_extremity_amputation_among_patien...
# 134                       pqi_14_uncontrolled_diabetes
# 165  pqi_16_lower_extremity_amputation_among_patien...
# 104                     pqi_12_urinary_tract_infection
# 95                          pqi_11_bacterial_pneumonia
# 156  pqi_16_lower_extremity_amputation_among_patien...
# 151                    pqi_15_asthma_in_younger_adults
# 150                    pqi_15_asthma_in_younger_adults
# 26              pqi_3_diabetes_long_term_complications
# 117                    pqi_13_angina_without_procedure
# 52                                  pqi_7_hypertension
# 130                       pqi_14_uncontrolled_diabetes
# 152                    pqi_15_asthma_in_younger_adults
# 148                    pqi_15_asthma_in_younger_adults
# 157  pqi_16_lower_extremity_amputation_among_patien...
# 147                    pqi_15_asthma_in_younger_adults
# 143                    pqi_15_asthma_in_younger_adults
# 27              pqi_3_diabetes_long_term_complications
# 40                pqi_5_copd_or_asthma_in_older_adults
# 66                                 pqi_8_heart_failure
# 167  pqi_16_lower_extremity_amputation_among_patien...
# 13                           pqi_2_perforated_appendix
# 53                                  pqi_7_hypertension
# 144                    pqi_15_asthma_in_younger_adults
# 92                          pqi_11_bacterial_pneumonia
# 79                                  pqi_10_dehydration
# 131                       pqi_14_uncontrolled_diabetes
# 118                    pqi_13_angina_without_procedure
# 105                     pqi_12_urinary_tract_infection
#
#                                  indicator_2  correlation
# 67    pqi_3_diabetes_long_term_complications     0.770318
# 161                      pqi_8_heart_failure     0.754825
# 107     pqi_5_copd_or_asthma_in_older_adults     0.714779
# 158   pqi_3_diabetes_long_term_complications     0.702959
# 94      pqi_5_copd_or_asthma_in_older_adults     0.695201
# 111               pqi_11_bacterial_pneumonia     0.678049
# 81      pqi_5_copd_or_asthma_in_older_adults     0.674903
# 97                        pqi_10_dehydration     0.644036
# 68      pqi_5_copd_or_asthma_in_older_adults     0.627826
# 106   pqi_3_diabetes_long_term_complications     0.624238
# 41    pqi_3_diabetes_long_term_complications     0.616891
# 109                      pqi_8_heart_failure     0.616595
# 133     pqi_5_copd_or_asthma_in_older_adults     0.574561
# 138           pqi_12_urinary_tract_infection     0.567810
# 132   pqi_3_diabetes_long_term_complications     0.533090
# 110                       pqi_10_dehydration     0.530644
# 164           pqi_12_urinary_tract_infection     0.519353
# 159     pqi_5_copd_or_asthma_in_older_adults     0.502412
# 136                       pqi_10_dehydration     0.492488
# 83                       pqi_8_heart_failure     0.488434
# 69                        pqi_7_hypertension     0.484495
# 93    pqi_3_diabetes_long_term_complications     0.478215
# 91   pqi_1_diabetes_short_term_complications     0.468039
# 80    pqi_3_diabetes_long_term_complications     0.465284
# 54    pqi_3_diabetes_long_term_complications     0.459965
# 135                      pqi_8_heart_failure     0.451257
# 137               pqi_11_bacterial_pneumonia     0.448311
# 153             pqi_14_uncontrolled_diabetes     0.441070
# 96                       pqi_8_heart_failure     0.436428
# 160                       pqi_7_hypertension     0.427982
# ..                                       ...          ...
# 39   pqi_1_diabetes_short_term_complications     0.300328
# 162                       pqi_10_dehydration     0.296802
# 134                       pqi_7_hypertension     0.295593
# 165          pqi_13_angina_without_procedure     0.279945
# 104  pqi_1_diabetes_short_term_complications     0.279931
# 95                        pqi_7_hypertension     0.254765
# 156  pqi_1_diabetes_short_term_complications     0.230292
# 151           pqi_12_urinary_tract_infection     0.229587
# 150               pqi_11_bacterial_pneumonia     0.222826
# 26   pqi_1_diabetes_short_term_complications     0.200468
# 117  pqi_1_diabetes_short_term_complications     0.190898
# 52   pqi_1_diabetes_short_term_complications     0.170215
# 130  pqi_1_diabetes_short_term_complications     0.139890
# 152          pqi_13_angina_without_procedure     0.131822
# 148                      pqi_8_heart_failure     0.113180
# 157                pqi_2_perforated_appendix     0.083918
# 147                       pqi_7_hypertension     0.078853
# 143  pqi_1_diabetes_short_term_complications     0.067592
# 27                 pqi_2_perforated_appendix     0.058372
# 40                 pqi_2_perforated_appendix     0.027580
# 66                 pqi_2_perforated_appendix     0.019008
# 167          pqi_15_asthma_in_younger_adults     0.013666
# 13   pqi_1_diabetes_short_term_complications     0.004560
# 53                 pqi_2_perforated_appendix    -0.052351
# 144                pqi_2_perforated_appendix    -0.054180
# 92                 pqi_2_perforated_appendix    -0.054807
# 79                 pqi_2_perforated_appendix    -0.080467
# 131                pqi_2_perforated_appendix    -0.111286
# 118                pqi_2_perforated_appendix    -0.134933
# 105                pqi_2_perforated_appendix    -0.150106
#
# [78 rows x 3 columns]
